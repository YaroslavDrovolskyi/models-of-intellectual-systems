# %% [markdown]
# <h1 style="text-align: center;">Звіт до лабораторної роботи №1</h1>
# <h2 style="text-align: center;">з предмету "Моделі інтелектуальних систем"</h2>
# <h3 style="text-align: center;">Дровольського Ярослава, ІПС-42</h3>
# <h3 style="text-align: center;">Варіант №2</h3>
#
# <div style="page-break-after: always;"></div>

# %% [markdown]
# **Тема:** Основи роботи в середовищі Jupyter Notebook
#
# **Мета:** отримати навички у встановленні, налаштуванні та
# основах роботи з Jupyter Notebook.
#
# <div style="page-break-after: always;"></div>

# %% [markdown]
# <h1 style="text-align: center;">Буркіна-Фасо</h1>
#
# <h2 style="text-align: center;">Загальна характеристика</h2>
#
# **Буркіна́-Фасо́** (фр. Burkina Faso) — незалежна держава у Західній Африці. Територія — 273 187 км², населення — 17,6 млн осіб (станом на 2013 рік).  Столиця — Уагадугу.
#
# ![Розташування країни](resources/location.png)
# *Розташування країни*
#
# ### Походження назви
# Назва означає «батьківщина чесних людей» (в перекладі з мови мооре «буркіна» — «чесні люди», в перекладі з мови дьюла «Фасо» — «вітчизна»). Інша версія перекладу — «країна гідних людей». Вживається також скорочена назва Буркіна (Burkina), прикметник від назви країни — буркінійський, буркінабський (на фула та французькою — Burkinabè).
#
# ### Фізико-географічне положення
# *Детальніше:* [Географія Буркіна-Фасо](https://uk.wikipedia.org/wiki/%D0%91%D1%83%D1%80%D0%BA%D1%96%D0%BD%D0%B0-%D0%A4%D0%B0%D1%81%D0%BE)
#
# Держава знаходиться в Західній Африці. Територія країни простяглася із заходу на схід на 845 км, а з півночі на південь на 645 км. На північному заході межує з Малі (спільний кордон — 1325 км); на північному сході — з Нігером (622 км); на півдні — з Беніном (386 км), Того (131 км), Ганою (602 км), Кот-д'Івуаром (545 км). Країна не має виходу до моря.
#
# Рельєф — хвилясте плато з нечастими низькими горбами висотою до 500 метрів. Плато замкнено пагорбами на заході і південно-сході; витоки річки Вольта; напівпустелі на півночі, ліси і фермерські землі на півдні.
#
# На південному заході — гори до 747 м (гора Тена-Куру). Клімат субекваторіальний, характеризується наявністю трьох основних сезонів: прохолодний сухий сезон продовжується з листопада по березень, спекотний сухий — з березня по травень, спекотний вологий — іншу частину року. Найбільші річки — Чорна Вольта, Біла Вольта. Багато шкідливих комах, зокрема, малярійні комарі, мухи цеце (переносник сонної хвороби), терміти та сарана.
#
#
# ![Рельєф країни](https://upload.wikimedia.org/wikipedia/commons/7/78/Burkina_Faso_relief_location_map.jpg)
#
#
# *Рельєф країни*

# %% [markdown]
# <h2 style="text-align: center;">Населення</h2>
#
# *Детальніше:* [Населення Буркіна-Фасо](https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%91%D1%83%D1%80%D0%BA%D1%96%D0%BD%D0%B0-%D0%A4%D0%B0%D1%81%D0%BE)
#
# Чисельність населення країни 2015 року становила 18,931 млн осіб (60-те місце у світі). Чисельність буркінабців стабільно збільшується, народжуваність 2015 року становила 42,03 ‰ (5-те місце у світі), смертність — 11,72 ‰ (28-ме місце у світі), природний приріст — 3,03 % (7-ме місце у світі).
#
# Густота населення країни 2015 року становила 66,2 особи/км² (148-ме місце у світі).
#
# **Рівень урбанізації** в 2000 році становив 16 %. Головні міста держави: Уагадугу (465 тис. осіб), Бобо-Діуласо (228 тис. осіб), Кудугу (51 тис. осіб).
#
# <!--
# ![Чисельність населення в країні із 1960 по 2010 рік](https://upload.wikimedia.org/wikipedia/commons/2/26/Burkina-Faso-Demography.png)
# -->
#
# ![Чисельність населення в країні із 1960 по 2010 рік](resources/Burkina-Faso-Demography.png)
#
# *Чисельність населення в країні із 1960 по 2010 рік*
#
# ### Відтворення
# Народжуваність в Буркіна-Фасо, станом на 2015 рік, дорівнює 42,03 ‰ (5-те місце у світі). Коефіцієнт потенційної народжуваності 2015 року становив 5,86 дитини на одну жінку (6-те місце у світі). Середній вік матері при народженні першої дитини становив 19,4 року, медіанний вік для жінок — 25-29 років (оцінка на 2010 рік).
#
# Смертність в Буркіна-Фасо 2015 року становила 11,72 ‰ (28-ме місце у світі). Природний приріст населення в країні 2015 року становив 3,03 % (7-ме місце у світі).
#
# Середній вік, коли чоловіки беруть перший шлюб дорівнює 24,3 року, жінки — 17,9 року, загалом — 21,1 року (дані за 2010 рік).
#
# ### Вікова структура
# Середній вік населення Буркіна-Фасо становить 17,2 року (221-ше місце у світі): для чоловіків — 17, для жінок — 17,3 року. Очікувана середня тривалість життя 2015 року становила 55,12 року (210-те місце у світі), для чоловіків — 53,1 року, для жінок — 57,21 року.
#
# **Вікова структура** населення Буркіна-Фасо, станом на 2015 рік, мала такий вигляд:
#
# - ***діти*** віком до 14 років — 45,2 % (4 286 569 чоловіків, 4 270 357 жінок);
# - ***молодь*** віком 15—24 роки — 20,08 % (1 909 090 чоловіків, 1 892 273 жінки);
# - ***дорослі*** віком 25—54 роки — 29,13 % (2 799 042 чоловіка, 2 716 439 жінок);
# - особи ***передпохилого віку*** (55—64 роки) — 3,14 % (253 423 чоловіка, 340 599 жінок);
# - особи ***похилого віку*** (65 років і старіші) — 2,45 % (174 647 чоловіків, 289 247 жінок)
#
#
# ![Статево-вікова піраміда населення країни, 2016 рік](https://upload.wikimedia.org/wikipedia/commons/a/a4/Population_pyramid_of_Burkina_Faso_2016.png)
#
#
# *Статево-вікова піраміда населення країни, 2016 рік*
#
# </br>
#
# **Статеве співвідношення** (згідно із оцінкою 2015 року):
# - *при народженні* — 1,03 особи чоловічої статі на 1 особу жіночої;
# - у віці *до 14 років* — 1 особи чоловічої статі на 1 особу жіночої;
# - у віці *15—24 років* — 1,01 особи чоловічої статі на 1 особу жіночої;
# - у віці *25—54 років* — 1,03 особи чоловічої статі на 1 особу жіночої;
# - у віці *55—64 років* — 0,74 особи чоловічої статі на 1 особу жіночої;
# - у віці *за 64 роки* — 0,6 особи чоловічої статі на 1 особу жіночої;
# - *загалом* — 0,99 особи чоловічої статі на 1 особу жіночої.
#
#
#
# ### Расово-етнічний склад
#
# Головні етноси країни станом на 2010 рік подані у наведеній таблиці:
#
#
# <div style="display:flex; justify-content: center;">
#
# | Етнос   | Відсоток |
# | :----:  | :----:   |
# | мосі    | 52,5 %   |
# | фульбе  | 8,4 %    |
# | ґурма   | 6,8 %    |
# | бобо    | 4,8 %    |
# | грусі   | 4,5 %    |
# | сенуфо  | 4,4 %    |
# | біса    | 3,9 %    |
# | лобі    | 2,5 %    |
# | дагара  | 2,4 %    |
# | туареги | 1,9 %    |
# | діула   | 0,8 %    |
# | інші    | 7 %      |
#
# </div>
#
#
#
# ### Мови та релігії
#
# *Детальніше:* [мови](https://uk.wikipedia.org/w/index.php?curid=1834894), [релігії](https://uk.wikipedia.org/w/index.php?curid=1834897)
#
# Офіційна мова: ***французька***. Мовами ***суданської мовної родини*** користується 90 % населення держави.
#
# Відповідно до даних перепису 2006 **конфесійний склад населення** такий:
# - 61% мусульмани (більшість — суніти, меншість — шиїти, також є суфії (орден Тиджанійя) і салафіти);
# - 23% християни;
#     - 19% католики;
#     - 4% протестанти;
# - 15% послідовники традиційних вірувань.
#
#
# ### Освіта
#
# Рівень писемності 2015 року становив 36 % дорослого населення (віком від 15 років): 43 % — серед чоловіків, 29,3 % — серед жінок.
#
# Державні витрати на освіту становлять *4,5 % ВВП країни*, станом на 2014 рік (128-ме місце у світі).
#
# Середня тривалість освіти становить *8 років*, для хлопців — *до 8 років*, для дівчат — *до 7 років* (станом на 2013 рік).

# %% [markdown]
# <h2 style="text-align: center;">Державний устрій</h2>
#
# Буркіна-Фасо за формою правління є **напівпрезидентською республікою**, глава держави — президент. Згідно з **конституцією 1991 року** парламент може бути розпущений президентом. Глава держави обирається загальним голосуванням на 7 років (з 1 листопада 2014 року обов'язки тимчасово виконує — Мішель Кафандо). Глава уряду — прем'єр-міністр, який призначається президентом (з 1 листопада 2014 — Ісаак Зіда).
#
# Державний устрій — **унітарна держава**.
#
# > <span style="color:red">Політичні свободи у Буркіна-Фасо суворо обмежені. Трапляються випадки насильства над журналістами, представниками міжнародних громадських організацій, чи просто активними громадянами, котрі часто фінансуються державою.</span>
#
# ### Державна символіка
#
# **Державний прапор** затверджено 4 серпня 1984 року після військового перевороту капітана Томаса Санкари. Прапор складається з двох рівновеликих смуг панафриканських кольорів, верхньої червоної (символізує революцію), та нижньої зеленої (символізує природу країни). Посередині жовта п'ятипроменева зірка (світло соціалістичної революції, або мінеральних багатств).
#
# Прапор країни виглядає так:

# %%
# %%HTML
# <div style="display:flex; justify-content: center;">
# <svg xmlns="http://www.w3.org/2000/svg" width="450" height="300">
#
#   <rect width="450" height="150" fill="#EF3340" />
#
#   <!-- Green Stripe -->
#   <rect y="150" width="450" height="150" fill="#009739" />
#
#   <!-- Yellow Star -->
#   <polygon points="225,110 237,140 270,140 243,155 255,185 225,170 195,185 207,155 180,140 213,140" fill="#FFD100" />
# </svg>
# </div>
# Out:
# <div style="display:flex; justify-content: center;">
# <svg xmlns="http://www.w3.org/2000/svg" width="450" height="300">
#
#   <rect width="450" height="150" fill="#EF3340" />
#
#   <!-- Green Stripe -->
#   <rect y="150" width="450" height="150" fill="#009739" />
#
#   <!-- Yellow Star -->
#   <polygon points="225,110 237,140 270,140 243,155 255,185 225,170 195,185 207,155 180,140 213,140" fill="#FFD100" />
# </svg>
# </div>

# %% [markdown]
# **Державний герб** містить щит в кольорах національного прапора, який тримають два білих жеребця. Нижче якого національний девіз «Єдність, Прогрес, Правосуддя». Герб затверджено у 1997 році, він повторює герб Республіки Верхня Вольта до 1984 року.
#
# **Державний гімн**, пісня «Тільки одна ніч» *(фр. Une Seule Nuit)* був офіційно затверджений під час революції 1984 року. Слова і музику написав творець нової країни Томас Санкара.
#
# ### Парламент
#
# **Парламент** є двопалатним: нижня палата - [Національна Асамблея](https://uk.wikipedia.org/wiki/%D0%9F%D0%B0%D1%80%D0%BB%D0%B0%D0%BC%D0%B5%D0%BD%D1%82_%D0%91%D1%83%D1%80%D0%BA%D1%96%D0%BD%D0%B0-%D0%A4%D0%B0%D1%81%D0%BE) (111 депутатів обираються загальним голосуванням на 5-річний термін) і верхня палата - Палата Представників (178 депутатів обираються на термін 3 роки). У Буркіна-Фасо відсутня обов'язкова 50 % явка виборців.
#
# За результатами парламентських виборів, що відбулись 6 травня 2007 року, до Національної асамблеї увійшли такі політичні партії Буркіна-Фасо:
#
# Існує також **Конституційна палата**, що складається з десяти членів, а також **Економічна** і **Соціальна Ради**, які виконують суто консультативну роль.
#
# ### Результати виборів 2020 року
#
# *Детальніше:* [Загальні вибори у 2020 році](https://en.wikipedia.org/wiki/2020_Burkinab%C3%A8_general_election) *(англ.)*
#
# 22 листопада 2020 року в країні відбулися Загальні вибори Президента та Національної асамблеї.
#
# За їх результатами вже у першому турі президентом було переобрано чинного президента **Рок Марк Крістіан Каборе**.
# Розподіл голосів найпопулярніших кандидатів по регіонах виглядає так:
#
# <div style="display:flex; justify-content: center;">
#
# ![Розподіл голосів по регіонах між трьома найпопулярнішими кандидатами на президентських виборах 2020 року](resources/2020_Burkina_Faso_Presidential_Election_Results_Map.svg.png)
#
#
# | Кандидат   | К-сть голосів | % голосів |
# | :----:  | :----:   | :----:|
# | <span style="color:orange"> Рок Марк Крістіан Каборе </span>    | 1 645 229  | 57,74 |
# | <span style="color:red"> Eddie Komboïgo </span> *(англ.)*  | 442 693    | 15,54 |
# | <span style="color:green"> Zéphirin Diabré </span> *(англ.)*  | 354 988    | 12,46 |
#
# </div>
#
# <br/>
#
# За результатами цих виборів, **розподіл місць між партіями** у Національній асамблеї виглядав так:
#
# ![Розподіл місць у Національній асамблеї між партіями на виборах 2020 року](resources/Burkina_Faso_Assembl%C3%A9e_nationale_2020.svg)
#
#
# | Партія   | % голосів | Місць |
# | :----:  | :----:   | :----:|
# | <span style="color:#FFA500"> People's Movement for Progress </span> *(англ.)*  | 34,59    | 56 |
# | <span style="color:#E5321C"> Congress for Democracy and Progress </span> *(англ.)*  | 13,27 | 20 |
# | <span style="color:#008800"> Union for Progress and Reform </span> *(англ.)*  | 10,18 | 12 |
# | <span style="color:#4393AD"> New Era for Democracy </span> *(англ.)*  | 5,57 | 13 |
# | <span style="color:#FFEF00"> Alliance for Democracy and Federation – African Democratic Rally </span> *(англ.)*  | 2,47 | 3 |
# | <span style="color:#DE144A"> Union for Rebirth / Sankarist Party </span> *(англ.)*  | 2,45 | 5 |
# | <span style="color:#FEDD72"> Patriotic Rally for Integrity </span> *(англ.)*  | 2,40 | 3 |
# | <span style="color:#4E9127"> Party for Development and Change </span> *(англ.)*  | 2,01 | 3 |
# | <span style="color:#F68121"> Movement for the Future Burkina Faso </span> *(англ.)*  | 1,97 | 4 |
# | <span style="color:#F2E701"> National Convention for Progress </span> *(англ.)*  | 1,32 | 2 |
# | <span style="color:#0465AA"> Act together </span> *(англ.)*  | 1,29 | 2 |
# | <span style="color:#EC5D25"> 	Pan-African Alliance for Refoundation </span> *(англ.)*  | 1,06 | 1 |
# | <span style="color:#44ba7d"> 	Progressives United for Renewal </span> *(англ.)*  | 1,03 | 1 |
# | <span style="color:#0B9D06"> 	Party for Democracy and Socialism/Metba </span> *(англ.)*  | 0,99 | 1 |
# | <span style="color:#007C3D"> 	Convergence for Progress and Solidarity-Generation 3 </span> *(англ.)*  | 0,74 | 1 |
#
#
# <br/>
#
# 24 січня 2022 року в країні стався державний переворот.
#
# ### Адміністративно-територіальний поділ
#
# Буркіна-Фасо розділена на 13 областей, 45 провінцій і 301 департамент.
#
# **Перелік областей:**
#
# <div style="display:flex; justify-content: center;">
#
# | № | Область  | Площа, км² | Населення (2006 рік), чол. |
# | --:| :----:              | :----: | :----:    |
# | 1  | Букле-ду-Мухун      | 34 479 | 1 434 847 |
# | 2  | Каскади             | 16 663 |   524 956 |
# | 3  | Центральна          |  2 805 | 1 523 980 |
# | 4  | Східно-Центральна   | 14 852 | 1 132 023 |
# | 5  | Північно-Центральна | 19 508 | 1 203 073 |
# | 6  | Західно-Центральна  | 21 853 | 1 183 473 |
# | 7  | Південно-Центральна | 11 313 |   638 379 |
# | 8  | Східна              | 46 256 | 1 209 399 |
# | 9  | Верхні Басейни      | 26 606 | 1 410 284 |
# | 10 | Північна            | 17 601 | 1 182 770 |
# | 11 | Центральне Плато    |  8 545 |  	647 516 |
# | 12 | Сахель              | 36 130 | 	808 928 |
# | 13 | Південно-Західна    | 16 576 |   623 056 |
#
# </div>
#
# ![Області Буркіна-Фасо](resources/regions.png)
#
# *Області Буркіна-Фасо*
#
# </br>
#
# **Поділ областей на провінції:**
#
# 1. Букле-ду-Мухун
#     - Бале
#     - Банва
#     - Коссі
#     - Мухун
#     - Наяла
#     - Суру
# 2. Каскади
#     - Комое
#     - Лераба
# 3. Центральна
#     - Кадіого
# 4. Східно-Центральна
#     - Булгу
#     - Кульпелого
#     - Курітенга
# 5. Північно-Центральна
#     - Бам
#     - Наментенга
#     - Санматенга
# 6. Західно-Центральна
#     - Булькіємде
#     - Сангіє
#     - Сиссілі
#     - Зіро
# 7. Південно-Центральна
#     - Базега
#     - Нахурі
#     - Зундвеого
# 8. Східна
#     - Няня
#     - Ґурма
#     - Комонджарі
#     - Комп'єнга
#     - Тапоа
# 9. Верхні Басейни
#     - Уе
#     - Кенедугу
#     - Тюї
# 10. Північна
#     - Лорум
#     - Пассоре
#     - Ятенга
#     - Зондома
# 11. Центральне Плато
#     - Ганзургу
#     - Курвеого
#     - Убрітенга
# 12. Сахель
#     - Удалан
#     - Сено
#     - Сум
#     - Яга
# 13. Південно-Західна
#     - Бугуріба
#     - Іоба
#     - Нумб'єль
#     - Поні
#
# ![Карта провінцій Буркіна-Фасо](resources/1280px-Burkina_Faso_provinces_named.png)
#
# *Карта провінцій Буркіна-Фасо*

# %% [markdown]
# <h2 style="text-align: center;">Видатні персоналії</h2>
#
# **Список видатних персоналій** Буркіна-Фасо:
#
# - Режисери
#     - Sarah Bouyain (1968)
#     - Gaston Kaboré (1951)
#     - Fanta Régina Nacro (1962)
#     - Idrissa Ouedraogo (1954)
# - Політики
#     - Boureima Badini - міністр юстиції у 1999 - 2007 роках
#     - Laurent Bado - кандидат в президенти у 2005 році
#     - Ali Barraud - міністр охорони здоров'я
#     - Djibril Bassolé - міністр закордонних справ
#     - Juliette Bonkoungou - посол Буркіна-Фасо в Канаді
#     - Blaise Compaoré - Президент із 1987 року
#     - Noellie Marie Béatri Damiba - журналіст та дипломат
# - Спортсмени
#     - Joris Bado - баскетболіст
#     - Tanguy Barro - футболіст
#     - Abdoulaye Cissé - футболіст
#     - Brahima Cissé - футболіст
#     - Daouda Compaoré - футболіст
#     - Madou Dossama - футболіст
#     - Bèbè Kambou - футболіст
#     - Cheick Sanou - стронгмен
#
# *Детальніше:* [Видатні персоналії Буркіна-Фасо](https://en.wikipedia.org/wiki/List_of_Burkinabes) *(англ.)*

# %% [markdown]
# <h2 style="text-align: center;">Пам'ятки культури та природи</h2>
#
# Пам'ятки культури:
# - ***Національний музей.*** Заснований в 1962 році, музей донині залишається досить функціональним, залучаючи відвідувачів комбінацією традиційних сільських будинків, які демонструють побут та культуру племен, що населяють країну; бібліотека музею також містить велику кількість матеріалу про культуру країни та народи, що її населяють.
# - ***Гранітні пам'ятники Лоанго***. У містечку Лоанго, що поблизу міста Зініарі, знаходиться гранітне святилище. В дійсності, Лоанго широко відомо по всьому світу серед скульпторів, які один раз на рік з'їжджаються сюди і вирізують з каменю все нові скульптури. Цей захід являє сосбой прекрасну можливість зустріти великих скульпторів сучасності та перейняти їх майстерність. Творіння часом незвичайні і таємничі.
# - ***Стара мечеть Бобо Діуласо***. У центрі другого за населенням міста Буркіна Фасо, в районі Діулассоба, знаходиться велика стара мечеть, побудована в 1890 році, що є чудовим зразком релігійної архітектури Сахеля. Доступ до мечеті для туристів можливий тільки рано вранці.
# - ***Археологічний музей і кам'яні скульптури Побе Менгао***. Як музей, так і кам'яні скульптури представляють собою історію життя «чесних людей» (Буркіна-Фасо — країна чесних людей)
# - ***Туристський табір***. Єдине місто буркінійського Сахеля, що володіє необхідною інфраструктурою, зазвичай служить базовим табором туристам, які подорожують по півночі країни.
#
#
# Пам'ятки природи:
# - ***Парк Бангр Веугу.*** Розташований в центральній частині столиці країни Уагадугу. У 2006 році мандрівники відзначали, що "в міському парку Бангр Веугу виростає більше 360 видів рослин і мешкає 160 видів птахів і 40 видів тварин, наприклад антилопи, крокодили, мавпи і білки. Інфраструктурні об'єкти парку: музей, присвячений тваринному світу, спортивний сектор, дитячий сектор «Парк Фасо» і ресторан.
# - ***Природний парк Зініарі***. У сафарі-парку Зініарі в неволі міститься велика кількість тварин. Це прекрасне місце для того, щоб подивитися на слонів, левів, антилоп та інших представників тваринного світу. Також туристи можуть відвідати маєток президента Блеза Компаоре, розташований неподалік.
# - ***Священні крокодили Сабу***. Місто Кудугу відоме завдяки священним крокодилам які мешкають в прилеглому містечку Сабу. В дійсності, шанобливість місцевих жителів щодо крокодилів пов'язана не тільки з релігійними культами, а й з більш утилітарними мотивами: крокодили абсолютно нешкідливі і є можливість фотографуватися на пам'ять з ними, на чому жителі і заробляють гроші.
# - ***Останці Синду***. Останці, що представляють собою виходи пісковика, включені в список природної спадщини ЮНЕСКО.
# - ***Національні парки Арлі і Дубль-В (W)***
# - ***Заповідники та мисливські угіддя Назінга***
# - ***Скелі Гобнаугу***
#
# Детальніше про туризм в Буркіна-Фасо можна почитати за [посиланням](https://uk.wikipedia.org/wiki/%D0%A2%D1%83%D1%80%D0%B8%D0%B7%D0%BC_%D1%83_%D0%91%D1%83%D1%80%D0%BA%D1%96%D0%BD%D0%B0-%D0%A4%D0%B0%D1%81%D0%BE).

# %% [markdown]
# <h2 style="text-align: center;">Корисна інформація від МЗС Украни про Буркіна-Фасо</h2>
#
# *Детальніше:* [Довідка від МЗС України](https://tripadvisor.mfa.gov.ua/?p=456)
#
#
# ### Адреса та номери телефонів закордонної дипломатичної установи відповідальності
#
# > **Посольство України в Туніській Республіці**
# <br/> *Адреса*: `7, rue Saint Fulgence, Notre Dame, 1002, Tunis`.
# <br/> *Номер* телефону: `+216 71 849 861`
# <br/> *Номер гарячої лінії*: `+216 941 273 42`
# <br/> *Електронна адреса*: emb_tn@mfa.gov.ua
# <br/> *Посилання на сайт ЗДУ*: http://tunis.mfa.gov.ua
#
#
#
# ### Корисні телефони в країні
#
# >*Поліція*: `17` або `50 30 63 83`
# <br/> *Жандармеріят*: `16`, або `80-00-11-45`
# <br/> *Швидка*: Кожен клінічний центр або лікарня мають власний номер виклику швидкої допомоги. Краще дізнатися про такі номери на місці заздалегідь.
# <br/> *Пожежна служба*: `18`
#
#
# ### Загальна інформація
#
# **Режим в’їзду для громадян України**: Візовий.
# При в’їзді в країну вимагається сертифікат міжнародного зразка про вакцинацію від жовтої лихоманки.
#
# #### Митні правила
# **Валютні питання.** Декларування валюти при в’їзді в країну не вимагається. Також відсутні обмеження щодо кількості дозволеної для ввозу та вивозу валюти.
# Митні органи Буркіна-Фасо можуть запроваджувати суворі правила, пов’язані з вивозом з країни таких предметів, як маски, релігійні атрибути, старожитності. За отриманням більш докладної інформації слід звертатися до консульських співробітників під час отримання в’їзної візи до Буркіна-Фасо.
#
# **Подорожі автомобілем.** Посвідчення водія українського зразка в Буркіна-Фасо не визнаються.
#
# **Культурні, релігійні та побутові рекомендації.** Буркіна-Фасо – мусульманська країна, у зв’язку з чим необхідно дотримуватися місцевих законів, звичаїв і традицій, а також поважати почуття місцевих мешканців.
# Під час місяця Рамадан рекомендовано уникати вживання їжі й напоїв та паління в громадських місцях.
# Злочини, пов’язані з наркотиками, суворо караються за місцевим законодавством.
# Не рекомендується фотографувати військові або інші урядові об’єкти.
# При собі завжди необхідно мати паспорт з дійсною візою, насамперед – за межами столиці, де існує велика ймовірність виникнення необхідності його пред’явлення.
#
#
# ### Безпекова ситуація
#
# #### Загальний опис
#
# Протягом останніх років Буркіна-Фасо пережила низку внутрішньополітичних потрясінь, що у свою чергу відобразилося на безпековій ситуації в цій країні. В державі фіксувалися численні демонстрації, частина яких завершилася актами  насильства. У 2016 році в країні мав місце терористичний напад, спрямований, насамперед, проти іноземних громадян. У результаті зазначеної терористичної акції в числі загиблих іноземців були й громадяни України.
#
# #### Характеристика регіонів
# Найбільш небезпечними регіонами Буркіна-Фасо вважається східна та південно-східна частини країни, де проходить державний кордон  з Нігером, Того та Беніном. На півночі країни слід уникати відвідування регіонів суміжних з Малі.
#
# #### Рекомендації
#
# Рекомендуємо утримуватися від подорожей до регіонів північніше від м.Булса, де існує загроза, пов’язана з можливістю проникнення до країни терористичних груп з території Малі та Нігеру, які здебільшого практикують викрадення іноземців.
# За останній період в державі були зафіксовані численні демонстрації, частина яких завершилася актами  насильства. Необхідно уникати місць, де відбуваються подібні акції.
#
# По можливості потрібно уникати нічних подорожей, оскільки існує високий ризик збройних пограбувань. У країні фіксується високий рівень вуличної злочинності, пов’язаної з крадіжками мобільних телефонів, гаманців та інших цінностей, особливо в місцях із значним скупченням людей, зокрема, в районі центрального ринку чи розташування офісу ООН. Пересуватися містом рекомендується групами та мати при собі копії, або оригінали паспортних документів.
# За винятком небагатьох магістралей, дороги в Буркіна-Фасо знаходяться у незадовільному стані, особливо під час сезону дощів (червень-вересень).
# Під час подорожей необхідно мати при собі запас питної води.
#
# ### Епідеміологічна ситуація
#
# Серйозну небезпеку для здоров’я подорожуючих становлять малярія та інфекційні хвороби кишково-шлункового тракту.
#
# Медична сфера в Буркіна-Фасо розвинена слабо, у зв’язку з чим отримання медичних послуг є проблематичним, особливо за межами столиці країни.
# Служби екстреної допомоги практично відсутні.
#
# У столиці існує мережа аптек, де можна придбати обмежений перелік необхідних лікарських засобів.

# %% [markdown]
# ## Алгоритм Евкліда

# %%
# finds the GCD (greatest common divisor) of two positive integers
def gcd(a,b):
    if a == 0:
        return b
        
    while b != 0:
        if a > b:
            a = a - b
        else:
            b = b - a
        
    return a


# checks if given string str represents positive integer
def is_positive_integer(str):
    return str.isdecimal() and int(str) > 0

def main():
    error = False
    
    a_str = input("Enter a (positive integer): ")
    b_str = input("Enter b (positive integer): ")
    
    if is_positive_integer(a_str) == False :
        print("ERROR: a must be a positive integer")
        error = True
    
    if is_positive_integer(b_str) == False :
        print("ERROR: b must be a positive integer")
        error = True

    if error == False :
        a = int(a_str)
        b = int(b_str)
        print("GCD(a,b) = " + str(gcd(a,b)))

# %% [markdown]
# **НСД для звичайних чисел:**

# %%
main()
# Out:
# Enter a (positive integer):  75
# Enter b (positive integer):  105
# GCD(a,b) = 15

# %% [markdown]
# **НСД для великих простих чисел:**

# %%
main()
# Out:
# Enter a (positive integer):  5054303
# Enter b (positive integer):  6816631
# GCD(a,b) = 1

# %% [markdown]
# **Тест, коли одне із вхідних чисел є від'ємним:**

# %%
main()
# Out:
# Enter a (positive integer):  -10
# Enter b (positive integer):  1000
# ERROR: a must be a positive integer

# %% [markdown]
# **Тест, коли один із вхідних рядків не є цілим числом:**

# %%
main()
# Out:
# Enter a (positive integer):  1000
# Enter b (positive integer):  1000.5
# ERROR: b must be a positive integer

# %% [markdown]
# **Тест, коли один із вхідних рядків не є числом:**

# %%
main()
# Out:
# Enter a (positive integer):  1000
# Enter b (positive integer):  thyjt
# ERROR: b must be a positive integer

# %% [markdown]
# </br>
#
# </br>
#
# **Діаграма активності (activity diagram)** для програми виглядає так:
#
# ![activity diagram](resources/activity-diagram.png)

# %% [markdown]
# <div style="page-break-after: always;"></div>
#
# [Посилання](https://github.com/YaroslavDrovolskyi/models-of-intellectual-systems/blob/main/lab1/lab1.ipynb) на цей блокнот на GitHub.
#
# [Посилання](https://nbviewer.org/github/YaroslavDrovolskyi/models-of-intellectual-systems/blob/main/lab1/lab1.ipynb) на цей блокнот в nbviewer.

# %% [markdown]
# **Висновок:** під час виконання лабораторної роботи, я отримав навички у встановленні, налаштуванні та основах роботи з Jupyter Notebook. Конкретніше, в процесі виконання лабораторної роботи, я встановив Anaconda, створив нове оточення для Python3 під назвою "notebook", налаштував поточну активну папку, оформив інформацію про Буркіна-Фасо (відповідно до мого варіанту), написав і протестував алгоритм Евкліда.
